# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('advertising.csv',sep=',')

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.shape
# Out:
# (200, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# Data Visualization

# %%
data.plot(x = 'TV',y = 'Sales', kind = 'scatter')
data.plot(x = 'Radio',y = 'Sales', kind = 'scatter')
plt.show()

# %%
sns.pairplot(data,kind='scatter')
plt.xlabel('Newspaper')
plt.ylabel=('Sales')
plt.show()

# %%
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)
plt.show()

# %% [markdown]
# Train and Test Data

# %%
x=data.drop("Sales",axis=1)
y=data["Sales"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([17.16476357, 20.53462007, 23.79409343,  9.37649013, 21.5543733 ,
#        12.70565614, 21.07501697,  8.65901616, 17.1649327 , 16.68880961,
#         8.81064333,  8.50772806, 18.49625978,  7.99206797, 12.6490433 ,
#        14.97505847,  8.21430901, 17.8315899 , 11.04517747, 20.39090382,
#        21.03789611, 13.04490145, 10.8380167 , 22.60805663,  9.29695504,
#         7.90993183, 20.86663772, 13.73422214, 10.77402998,  7.81466049,
#        15.93037797, 10.60011594, 20.96308621, 10.75971333, 21.62040645,
#        21.06641423, 12.04203253, 22.96452088, 12.50662839,  6.44808712,
#        11.90179615, 15.2260707 ,  9.96234937,  9.42826337, 17.17466348,
#         7.1773329 , 10.43383015, 15.20066012, 11.18582512, 11.67054682,
#        13.89305235, 14.59633742, 10.70250628,  9.41652667,  8.97328245,
#        12.50638395, 10.42520099, 25.10626171,  7.84829742, 15.75779955,
#        21.19652389, 16.98178637, 12.85633234, 10.04779017, 20.90930583,
#         7.47385489, 23.38321106,  7.05294977, 12.48595909, 10.00774974,
#        11.06136251,  9.04689085, 16.91371393, 17.95852957, 15.89957626,
#        18.17963341, 15.44454795, 19.09968582, 17.60004642, 21.79783342,
#        10.80918948, 14.15988184, 10.81051989, 18.05972437,  9.84975664,
#        17.58147353, 13.33125942, 23.58312182, 10.9430492 , 23.63386095,
#         7.38254404, 19.41523988, 25.3324475 , 21.06915309, 18.73704069,
#        16.38773921, 13.94272083, 11.25206238, 19.56083569, 15.42076638])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.907313434112335

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1.605957570767839

# %%
plt.plot(y_pred)

# %%
plt.plot(x_test,y_test)
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2_score(y_test,y_pred)
# Out:
# 0.907313434112335

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1.605957570767839
